# %% [markdown]
# # Extrai tweets

# %% [markdown]
# ## Play!

# %%
#!python get_tweets.py

# %% [markdown]
# # Entendendo a estrutura do JSON

# %%
import json

# %%
# Abrir o arquivo de Tweets e ler as linhas 
with open('colleted_tweets_2020-11-21-07-52-45.txt', 'r') as file:
    tweets = file.readlines()

# %%
# Primeira linha do Tweet
tweets[0]
# Out:
# '"{\\"created_at\\":\\"Sat Nov 21 10:52:40 +0000 2020\\",\\"id\\":1330101819566125056,\\"id_str\\":\\"1330101819566125056\\",\\"text\\":\\"RT @reconWaRRioRs: VP memberi penjelasan ttg persiapan vaksin c19 dll segala macam \\\\ud83d\\\\udc48ini nggk penting, kebijakan c19 bs berubah d era Trump,\\\\u2026\\",\\"source\\":\\"\\\\u003ca href=\\\\\\"http:\\\\/\\\\/twitter.com\\\\/download\\\\/android\\\\\\" rel=\\\\\\"nofollow\\\\\\"\\\\u003eTwitter for Android\\\\u003c\\\\/a\\\\u003e\\",\\"truncated\\":false,\\"in_reply_to_status_id\\":null,\\"in_reply_to_status_id_str\\":null,\\"in_reply_to_user_id\\":null,\\"in_reply_to_user_id_str\\":null,\\"in_reply_to_screen_name\\":null,\\"user\\":{\\"id\\":893606077811400704,\\"id_str\\":\\"893606077811400704\\",\\"name\\":\\"remote dunia \\\\ud83d\\\\udee1\\\\ufe0f\\",\\"screen_name\\":\\"inteldunia\\",\\"location\\":\\"Washington, DC\\",\\"url\\":null,\\"description\\":\\"Baca tulisan ku dari arah yg sebaliknya, Jika gunakan smartphone putar dul
# ...

# %%
# Em modo de leitura um mostra um novo arquivo json
with open('tweet.json', 'w') as f:
    json.dump(
        json.loads(tweets[0]), f
    )

# %%
# Mostra o tipo do dado
type(
    json.loads(tweets[0])
)
# Out:
# str

# %%
# Converte para dicionário 
json.loads(
    json.loads(tweets[0])
)
# Out:
# {'created_at': 'Sat Nov 21 10:52:40 +0000 2020',
#  'id': 1330101819566125056,
#  'id_str': '1330101819566125056',
#  'text': 'RT @reconWaRRioRs: VP memberi penjelasan ttg persiapan vaksin c19 dll segala macam 👈ini nggk penting, kebijakan c19 bs berubah d era Trump,…',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 893606077811400704,
#   'id_str': '893606077811400704',
#   'name': 'remote dunia 🛡️',
#   'screen_name': 'inteldunia',
#   'location': 'Washington, DC',
#   'url': None,
#   'description': 'Baca tulisan ku dari arah yg sebaliknya, Jika gunakan smartphone putar dulu 7 kali berlawanan arah jarum jam !! Agar kau bisa memahami isi Twitt ini.',
#   'translator_type': 'none',
#   'protected': False,
# ...

# %%
# Mostra o tipo do dado
type(
    json.loads(
        json.loads(tweets[0])
    )
)
# Out:
# dict

# %%
# Grava um novo arquivo json
# Fazendo o parse do tweet para um formato json e exportando para um arquivo 
with open('tweet.json', 'w') as f:
    json.dump(
        json.loads(
            json.loads(tweets[0])
        ), f
    )

# %%
json.loads(
    json.loads(tweets[0])
)
# Out:
# {'created_at': 'Sat Nov 21 10:52:40 +0000 2020',
#  'id': 1330101819566125056,
#  'id_str': '1330101819566125056',
#  'text': 'RT @reconWaRRioRs: VP memberi penjelasan ttg persiapan vaksin c19 dll segala macam 👈ini nggk penting, kebijakan c19 bs berubah d era Trump,…',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 893606077811400704,
#   'id_str': '893606077811400704',
#   'name': 'remote dunia 🛡️',
#   'screen_name': 'inteldunia',
#   'location': 'Washington, DC',
#   'url': None,
#   'description': 'Baca tulisan ku dari arah yg sebaliknya, Jika gunakan smartphone putar dulu 7 kali berlawanan arah jarum jam !! Agar kau bisa memahami isi Twitt ini.',
#   'translator_type': 'none',
#   'protected': False,
# ...

# %%
parsed_tweets = [json.loads(json.loads(i)) for i in tweets]

# %%
parsed_tweets[0]
# Out:
# {'created_at': 'Sat Nov 21 10:52:40 +0000 2020',
#  'id': 1330101819566125056,
#  'id_str': '1330101819566125056',
#  'text': 'RT @reconWaRRioRs: VP memberi penjelasan ttg persiapan vaksin c19 dll segala macam 👈ini nggk penting, kebijakan c19 bs berubah d era Trump,…',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 893606077811400704,
#   'id_str': '893606077811400704',
#   'name': 'remote dunia 🛡️',
#   'screen_name': 'inteldunia',
#   'location': 'Washington, DC',
#   'url': None,
#   'description': 'Baca tulisan ku dari arah yg sebaliknya, Jika gunakan smartphone putar dulu 7 kali berlawanan arah jarum jam !! Agar kau bisa memahami isi Twitt ini.',
#   'translator_type': 'none',
#   'protected': False,
# ...

# %%
parsed_tweets[1]
# Out:
# {'created_at': 'Sat Nov 21 10:52:40 +0000 2020',
#  'id': 1330101819826184194,
#  'id_str': '1330101819826184194',
#  'text': 'RT @ScottFishman: “Trump team will prove case within two weeks.” - @SidneyPowell1',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 3927040813,
#   'id_str': '3927040813',
#   'name': 'Sandystarr',
#   'screen_name': 'lynnrooey',
#   'location': None,
#   'url': None,
#   'description': 'NO DMs. Love our President Trump.... support our first responders, Ice,law enforcement,military!!! Go Navy !! Trump 2020 !!!!',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 1470,
#   'friends_count': 1315,
#   'listed_count': 52,
# ...

# %%
# Quantidade de tweets coletados
len(parsed_tweets)
# Out:
# 34800

# %% [markdown]
# # Acessando as chaves do JSON (Dicionário)

# %%
primeirotweet = parsed_tweets[1]

# %%
# Retorna apenas as chaves do nível superior
primeirotweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %%
# Retorna apenas os valores do nível superior
primeirotweet.values()
# Out:
# dict_values(['Sat Nov 21 10:52:40 +0000 2020', 1330101819826184194, '1330101819826184194', 'RT @ScottFishman: “Trump team will prove case within two weeks.” - @SidneyPowell1', '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', False, None, None, None, None, None, {'id': 3927040813, 'id_str': '3927040813', 'name': 'Sandystarr', 'screen_name': 'lynnrooey', 'location': None, 'url': None, 'description': 'NO DMs. Love our President Trump.... support our first responders, Ice,law enforcement,military!!! Go Navy !! Trump 2020 !!!!', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1470, 'friends_count': 1315, 'listed_count': 52, 'favourites_count': 5806, 'statuses_count': 74070, 'created_at': 'Sat Oct 17 17:15:18 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url'
# ...

# %%
# retorna os itens em formato de tuplas
primeirotweet.items()
# Out:
# dict_items([('created_at', 'Sat Nov 21 10:52:40 +0000 2020'), ('id', 1330101819826184194), ('id_str', '1330101819826184194'), ('text', 'RT @ScottFishman: “Trump team will prove case within two weeks.” - @SidneyPowell1'), ('source', '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'), ('truncated', False), ('in_reply_to_status_id', None), ('in_reply_to_status_id_str', None), ('in_reply_to_user_id', None), ('in_reply_to_user_id_str', None), ('in_reply_to_screen_name', None), ('user', {'id': 3927040813, 'id_str': '3927040813', 'name': 'Sandystarr', 'screen_name': 'lynnrooey', 'location': None, 'url': None, 'description': 'NO DMs. Love our President Trump.... support our first responders, Ice,law enforcement,military!!! Go Navy !! Trump 2020 !!!!', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1470, 'friends_count': 1315, 'listed_count': 52, 'favourites_count': 5806, 'statuses_count': 74070, 'created_at': 'Sat Oct 1
# ...

# %% [markdown]
# ### Acessando conteúdo de algumas chaves de primeiro nível

# %%
primeirotweet['created_at']
# Out:
# 'Sat Nov 21 10:52:40 +0000 2020'

# %%
primeirotweet['id']
# Out:
# 1330101819826184194

# %%
primeirotweet['id_str']
# Out:
# '1330101819826184194'

# %%
primeirotweet['truncated']
# Out:
# False

# %%
# chave com o valor - null
# Python retorna nada (vazio)
primeirotweet['geo']

# %%
primeirotweet['text']
# Out:
# 'RT @ScottFishman: “Trump team will prove case within two weeks.” - @SidneyPowell1'

# %% [markdown]
# ### Acessando conteúdo de algumas chaves de segundo nível

# %%
primeirotweet['user']
# Out:
# {'id': 3927040813,
#  'id_str': '3927040813',
#  'name': 'Sandystarr',
#  'screen_name': 'lynnrooey',
#  'location': None,
#  'url': None,
#  'description': 'NO DMs. Love our President Trump.... support our first responders, Ice,law enforcement,military!!! Go Navy !! Trump 2020 !!!!',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 1470,
#  'friends_count': 1315,
#  'listed_count': 52,
#  'favourites_count': 5806,
#  'statuses_count': 74070,
#  'created_at': 'Sat Oct 17 17:15:18 +0000 2015',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
# ...

# %%
primeirotweet['user']['id']
# Out:
# 3927040813

# %%
primeirotweet['user']['name']
# Out:
# 'Sandystarr'

# %%
primeirotweet['user']['screen_name']
# Out:
# 'lynnrooey'

# %%
primeirotweet['user']['location']

# %%
primeirotweet['user']['friends_count']
# Out:
# 1315

# %% [markdown]
# # Acessando conteúdo de algumas chaves com mais níveis aninhados

# %%
primeirotweet['retweeted_status']
# Out:
# {'created_at': 'Fri Nov 20 20:24:36 +0000 2020',
#  'id': 1329883362803245057,
#  'id_str': '1329883362803245057',
#  'text': '“Trump team will prove case within two weeks.” - @SidneyPowell1',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 33417701,
#   'id_str': '33417701',
#   'name': 'Scott Fishman',
#   'screen_name': 'ScottFishman',
#   'location': 'Carolina',
#   'url': 'https://RealestApparel.com',
#   'description': '🇺🇸 Coach/Trainer/Mentor to Hundreds of the Best Athletes on Six Continents (14+ years) | Author | Founded Realest (@RealestUSA) | "The People\'s Coach"',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': True,
#   'followers_count': 108514,
#   'friends_count': 53779,
# ...

# %%
primeirotweet['retweeted_status']['id']
# Out:
# 1329883362803245057

# %%
primeirotweet['retweeted_status']['created_at']
# Out:
# 'Fri Nov 20 20:24:36 +0000 2020'

# %%
# pegando o indices do primeiro usuário mencionado 
primeirotweet['retweeted_status']['entities']['user_mentions'][0]['name']
# Out:
# 'Sidney Powell 🇺🇸⭐⭐⭐'

# %% [markdown]
# # Transformar os Tweets em uma estrutura Relacional

# %%
import pandas as pd

# %%
teste = pd.DataFrame(primeirotweet)

# %%
# Não adequado a leitura 
teste.head()
# Out:
#                                  created_at                   id  \
# id           Sat Nov 21 10:52:40 +0000 2020  1330101819826184194
# id_str       Sat Nov 21 10:52:40 +0000 2020  1330101819826184194
# name         Sat Nov 21 10:52:40 +0000 2020  1330101819826184194
# screen_name  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194
# location     Sat Nov 21 10:52:40 +0000 2020  1330101819826184194
#
#                           id_str  \
# id           1330101819826184194
# id_str       1330101819826184194
# name         1330101819826184194
# screen_name  1330101819826184194
# location     1330101819826184194
#
#                                                           text  \
# id           RT @ScottFishman: “Trump team will prove case ...
# id_str       RT @ScottFishman: “Trump team will prove case ...
# name         RT @ScottFishman: “Trump team will prove case ...
# screen_name  RT @ScottFishman: “Trump team will prove case ...
# ...

# %%
teste.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df_tratado = pd.DataFrame(primeirotweet).reset_index(drop=True).iloc[:1]
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
#
#                                                 text  \
# 0  RT @ScottFishman: “Trump team will prove case ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ... quote_count reply_count retweet_count  \
# 0                    None  ...           0           0             0
#
#   favorite_count entities favorited retweeted  filter_level  lang  \
# 0              0      NaN     False     False           low    en
#
#     timestamp_ms
# 0  1605955960600
#
# [1 rows x 28 columns]

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df_tratado.drop(columns=['quote_count', 
                         'reply_count', 
                         'retweet_count', 
                         'favorite_count', 
                         'favorited', 
                         'retweeted',
                         'user',
                         'entities',
                         'retweeted_status'], inplace=True)

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'filter_level', 'lang',
#        'timestamp_ms'],
#       dtype='object')

# %%
primeirotweet['user']
# Out:
# {'id': 3927040813,
#  'id_str': '3927040813',
#  'name': 'Sandystarr',
#  'screen_name': 'lynnrooey',
#  'location': None,
#  'url': None,
#  'description': 'NO DMs. Love our President Trump.... support our first responders, Ice,law enforcement,military!!! Go Navy !! Trump 2020 !!!!',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 1470,
#  'friends_count': 1315,
#  'listed_count': 52,
#  'favourites_count': 5806,
#  'statuses_count': 74070,
#  'created_at': 'Sat Oct 17 17:15:18 +0000 2015',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
# ...

# %%
df_tratado['user_id'] = primeirotweet['user']['id']
df_tratado['user_id_str'] = primeirotweet['user']['id_str']
df_tratado['user_screen_name'] = primeirotweet['user']['screen_name']
df_tratado['user_location'] = primeirotweet['user']['location']
df_tratado['user_description'] = primeirotweet['user']['description']
df_tratado['user_protected'] = primeirotweet['user']['protected']
df_tratado['user_verified'] = primeirotweet['user']['verified']
df_tratado['user_followers_count'] = primeirotweet['user']['followers_count']
df_tratado['user_friends_count'] = primeirotweet['user']['friends_count']
df_tratado['user_created_at'] = primeirotweet['user']['created_at']

# %%
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
#
#                                                 text  \
# 0  RT @ScottFishman: “Trump team will prove case ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...     user_id user_id_str user_screen_name  \
# 0                    None  ...  3927040813  3927040813        lynnrooey
#
#   user_location                                   user_description  \
# 0          None  NO DMs. Love our President Trump.... support o...
#
#    user_protected user_verified user_followers_count user_friends_count  \
# ...

# %%
primeirotweet['entities']
# Out:
# {'hashtags': [],
#  'urls': [],
#  'user_mentions': [{'screen_name': 'ScottFishman',
#    'name': 'Scott Fishman',
#    'id': 33417701,
#    'id_str': '33417701',
#    'indices': [3, 16]},
#   {'screen_name': 'SidneyPowell1',
#    'name': 'Sidney Powell 🇺🇸⭐⭐⭐',
#    'id': 586707638,
#    'id_str': '586707638',
#    'indices': [67, 81]}],
#  'symbols': []}

# %%
user_mentions = []

for i in range(len(primeirotweet['entities']['user_mentions'])):
    dictbase = primeirotweet['entities']['user_mentions'][i].copy()
    dictbase.pop('indices', None)
    df = pd.DataFrame(dictbase, index=[0])
    df = df.rename(columns={
        'screen_name': 'entities_screen_name',
        'name': 'entities_name',
        'id': 'entities_id',
        'id_str': 'entities_id_str'
    })
    user_mentions.append(df)

# %%
user_mentions
# Out:
# [  entities_screen_name  entities_name  entities_id entities_id_str
#  0         ScottFishman  Scott Fishman     33417701        33417701,
#    entities_screen_name        entities_name  entities_id entities_id_str
#  0        SidneyPowell1  Sidney Powell 🇺🇸⭐⭐⭐    586707638       586707638]

# %%
user_mentions[0]
# Out:
#   entities_screen_name  entities_name  entities_id entities_id_str
# 0         ScottFishman  Scott Fishman     33417701        33417701

# %%
user_mentions[1]
# Out:
#   entities_screen_name        entities_name  entities_id entities_id_str
# 0        SidneyPowell1  Sidney Powell 🇺🇸⭐⭐⭐    586707638       586707638

# %%
dfs = []

for i in user_mentions:
    dfs.append(
        pd.concat([df_tratado.copy(), i], axis = 1)
    )

# %%
dfs[0]
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
#
#                                                 text  \
# 0  RT @ScottFishman: “Trump team will prove case ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
#
#                                     user_description user_protected  \
# 0  NO DMs. Love our President Trump.... support o...          False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                 1470               1315
#
#                   user_created_at entities_screen_name  entities_name  \
# ...

# %%
dfs[1]
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
#
#                                                 text  \
# 0  RT @ScottFishman: “Trump team will prove case ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
#
#                                     user_description user_protected  \
# 0  NO DMs. Love our President Trump.... support o...          False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                 1470               1315
#
#                   user_created_at entities_screen_name        entities_name  \
# ...

# %%
pd.concat(dfs, ignore_index = True)
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
# 1  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
#
#                                                 text  \
# 0  RT @ScottFishman: “Trump team will prove case ...
# 1  RT @ScottFishman: “Trump team will prove case ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
# 1                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
# 1                    None  ...
#
# ...

# %% [markdown]
# ## Criar uma função para o tratamento de todo os Tweets e converte para um DataFrame pandas

# %%
def tweet_to_df(tweet):
    
    try:
    
        df_tratado = pd.DataFrame(tweet).reset_index(drop=True).iloc[:1]

        df_tratado.drop(columns=['quote_count', 'reply_count', 'retweet_count', 
                                 'favorite_count', 'favorited', 'retweeted', 
                                 'user', 'entities', 'retweeted_status'], inplace=True)

        df_tratado['user_id'] = tweet['user']['id']
        df_tratado['user_id_str'] = tweet['user']['id_str']
        df_tratado['user_screen_name'] = tweet['user']['screen_name']
        df_tratado['user_location'] = tweet['user']['location']
        df_tratado['user_description'] = tweet['user']['description']
        df_tratado['user_protected'] = tweet['user']['protected']
        df_tratado['user_verified'] = tweet['user']['verified']
        df_tratado['user_followers_count'] = tweet['user']['followers_count']
        df_tratado['user_friends_count'] = tweet['user']['friends_count']
        df_tratado['user_created_at'] = tweet['user']['created_at']


        user_mentions = []
        for i in range(len(tweet['entities']['user_mentions'])):
            dictbase = tweet['entities']['user_mentions'][i].copy()
            dictbase.pop('indices', None)
            df = pd.DataFrame(dictbase, index=[0])
            df = df.rename(columns={
                'screen_name': 'entities_screen_name',
                'name': 'entities_name',
                'id': 'entities_id',
                'id_str': 'entities_id_str'
            })
            user_mentions.append(df)


        dfs = []
        for i in user_mentions:
            dfs.append(
                pd.concat([df_tratado.copy(), i], axis = 1)
            )


        df_final = pd.concat(dfs, ignore_index = True)
    
    except:
        
        return None
    
    
    return df_final

# %%
tweet_to_df(parsed_tweets[4])

# %%
parsed_tweets[4]
# Out:
# {'created_at': 'Sat Nov 21 10:52:40 +0000 2020',
#  'id': 1330101820430163970,
#  'id_str': '1330101820430163970',
#  'text': 'Absolutely unacceptable!',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1281107728711258113,
#   'id_str': '1281107728711258113',
#   'name': 'Black Diamond',
#   'screen_name': 'BlackDi04229689',
#   'location': None,
#   'url': None,
#   'description': 'An avid resister who believes in American Democracy. 2017 Poetry Hall of Fame Inductee and Activist/ Army Veteran',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 220,
#   'friends_count': 240,
#   'listed_count': 0,
#   'favourites_count': 23134,
#   'statuses_count': 25010,
# ...

# %% [markdown]
# ## Iterar e transformar todos os tweets

# %%
# %%time 

parseados = [tweet_to_df(tweet) for tweet in parsed_tweets]
# Out:
# CPU times: user 4min 8s, sys: 471 ms, total: 4min 8s
# Wall time: 4min 8s

# %%
tweetsnone = [i for i in parseados if i is None]

# %%
# Total de registros - None
len(tweetsnone)
# Out:
# 11118

# %%
# Eliminar as posições vazias (None) da lista
parseados = [i for i in parseados if i is not None]

# %%
# Total da base completa 
len(parsed_tweets)
# Out:
# 34800

# %%
# Total da base restante menos os None
len(parseados)
# Out:
# 23682

# %%
tratado = pd.concat(parseados, ignore_index=True)

# %%
tratado.head(5)
# Out:
#                        created_at                   id               id_str  \
# 0  Sat Nov 21 10:52:40 +0000 2020  1330101819566125056  1330101819566125056
# 1  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
# 2  Sat Nov 21 10:52:40 +0000 2020  1330101819826184194  1330101819826184194
# 3  Sat Nov 21 10:52:40 +0000 2020  1330101820472123392  1330101820472123392
# 4  Sat Nov 21 10:52:40 +0000 2020  1330101820430184449  1330101820430184449
#
#                                                 text  \
# 0  RT @reconWaRRioRs: VP memberi penjelasan ttg p...
# 1  RT @ScottFishman: “Trump team will prove case ...
# 2  RT @ScottFishman: “Trump team will prove case ...
# 3  RT @kohyu1952: この重要な記者会見の文字起こし全文がある。\nドミニオンはバイ...
# 4  RT @perlmutations: Allow me to address the ele...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/android" ...      False
# ...

# %% [markdown]
# # Ingestão de dados do Twtter para MySQL

# %%
import mysql
import pyodbc
import sqlalchemy
import os
from sqlalchemy import create_engine

# %%
import mysql
import pyodbc
import sqlalchemy
import os
from sqlalchemy import create_engine

database_username = 'root'
database_password = 'xxxxxx'
database_ip       = 'localhost'
database_name     = 'xxxxxx'

engine = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.format(database_username,
                                                                                  database_password,
                                                                                  database_ip,
                                                                                  database_name))

tratado.to_sql(name = 'twttes', con = engine, index = False, if_exists = 'append')
